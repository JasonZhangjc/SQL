# %% [markdown]
# ### Load the Data First

# %%
from google.cloud import bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="sql-bigquery-331719-5129dc99895e.json"

# %%
# Create a "Client" object
client = bigquery.Client()

# %%
# Construct a reference to the "hacker_news" dataset
dataset_ref = client.dataset("openaq", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %%
# List all the tables in the "hacker_news" dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset (there are four!)
for table in tables:  
    print(table.table_id)
# Out:
# global_air_quality

# %%
# Construct a reference to the "full" table
table_ref = dataset_ref.table("global_air_quality")

# API request - fetch the table
table = client.get_table(table_ref)

# %%
# Print information on all the columns in the "full" table in the "hacker_news" dataset
table.schema
# Out:
# [SchemaField('location', 'STRING', 'NULLABLE', 'Location where data was measured', (), None),
#  SchemaField('city', 'STRING', 'NULLABLE', 'City containing location', (), None),
#  SchemaField('country', 'STRING', 'NULLABLE', 'Country containing measurement in 2 letter ISO code', (), None),
#  SchemaField('pollutant', 'STRING', 'NULLABLE', 'Name of the Pollutant being measured. Allowed values: PM25, PM10, SO2, NO2, O3, CO, BC', (), None),
#  SchemaField('value', 'FLOAT', 'NULLABLE', 'Latest measured value for the pollutant', (), None),
#  SchemaField('timestamp', 'TIMESTAMP', 'NULLABLE', 'The datetime at which the pollutant was measured, in ISO 8601 format', (), None),
#  SchemaField('unit', 'STRING', 'NULLABLE', 'The unit the value was measured in coded by UCUM Code', (), None),
#  SchemaField('source_name', 'STRING', 'NULLABLE', 'Name of the source of the data', (), None),
#  SchemaField('latitude', 'FLOAT', 'NULLABLE', 'Latitude in decimal degrees. Precision >3 decimal points.', (), None),
#  SchemaField('longitude', 'FLOAT', 'NULLABLE', 'Longitude in decimal degrees. Precision >3 decimal points.', (), None),
#  SchemaField('averaged_over_in_hours', 'FLOAT', 'NULLABLE', 'The number of hours the value was averaged over.', (), None)]

# %%
# Preview the first five lines of the "full" table
client.list_rows(table, max_results=50).to_dataframe()
# Out:
#                                       location         city country pollutant  \
# 0                BTM Layout, Bengaluru - KSPCB    Bengaluru      IN        co
# 1                BTM Layout, Bengaluru - KSPCB    Bengaluru      IN       no2
# 2                BTM Layout, Bengaluru - KSPCB    Bengaluru      IN        o3
# 3                BTM Layout, Bengaluru - KSPCB    Bengaluru      IN      pm25
# 4                BTM Layout, Bengaluru - KSPCB    Bengaluru      IN       so2
# 5     BWSSB Kadabesanahalli, Bengaluru - KSPCB    Bengaluru      IN        co
# 6     BWSSB Kadabesanahalli, Bengaluru - KSPCB    Bengaluru      IN       no2
# 7                        BWSSB Kadabesanahalli    Bengaluru      IN        o3
# 8     BWSSB Kadabesanahalli, Bengaluru - KSPCB    Bengaluru      IN      pm25
# 9     BWSSB Kadabesanahalli, Bengaluru - KSPCB    Bengaluru      IN       so2
# 10                City Railway Station - KSPCB    Bengaluru      IN        co
# 11                City Railway Station - KSPCB    Bengaluru      IN       no2
# 12                City Railway Station - KSPCB    Bengaluru      IN      pm10
# 13                City Railway Station - KSPCB    Bengaluru      IN       so2
# 14                     SaneguravaHalli - KSPCB    Bengaluru      IN        co
# 15                     SaneguravaHalli - KSPCB    Bengaluru      IN       no2
# 16                     SaneguravaHalli - KSPCB    Bengaluru      IN      pm10
# 17                     SaneguravaHalli - KSPCB    Bengaluru      IN       so2
# 18                                         IIT      Chennai      IN        co
# 19                                         IIT      Chennai      IN       no2
# 20                                         IIT      Chennai      IN        o3
# 21                                         IIT      Chennai      IN      pm25
# 22                                         IIT      Chennai      IN       so2
# 23                           Alandur Bus Depot      Chennai      IN        co
# 24                           Alandur Bus Depot      Chennai      IN       no2
# 25                           Alandur Bus Depot      Chennai      IN        o3
# 26                           Alandur Bus Depot      Chennai      IN      pm25
# 27                           Alandur Bus Depot      Chennai      IN       so2
# 28                   Peenya, Bengaluru - KSPCB    Bengaluru      IN        co
# 29                   Peenya, Bengaluru - KSPCB    Bengaluru      IN       no2
# 30                   Peenya, Bengaluru - KSPCB    Bengaluru      IN      pm25
# 31                   Peenya, Bengaluru - KSPCB    Bengaluru      IN       so2
# 32             Sanathnagar - Hyderabad - TSPCB    Hyderabad      IN        co
# 33             Sanathnagar - Hyderabad - TSPCB    Hyderabad      IN        o3
# 34             Sanathnagar - Hyderabad - TSPCB    Hyderabad      IN      pm25
# 35             Sanathnagar - Hyderabad - TSPCB    Hyderabad      IN       so2
# 36                       AAQMS Karve Road Pune         Pune      IN        co
# 37                       AAQMS Karve Road Pune         Pune      IN        o3
# 38                       AAQMS Karve Road Pune         Pune      IN      pm10
# 39                       AAQMS Karve Road Pune         Pune      IN      pm25
# 40                       AAQMS Karve Road Pune         Pune      IN       so2
# 41  Maharashtra Pollution Control Board Bandra       Mumbai      IN        co
# 42  Maharashtra Pollution Control Board Bandra       Mumbai      IN       no2
# 43  Maharashtra Pollution Control Board Bandra       Mumbai      IN        o3
# 44  Maharashtra Pollution Control Board Bandra       Mumbai      IN      pm10
# 45  Maharashtra Pollution Control Board Bandra       Mumbai      IN      pm25
# 46  Maharashtra Pollution Control Board Bandra       Mumbai      IN       so2
# 47    Navi Mumbai Municipal Corporation Airoli  Navi Mumbai      IN      pm25
# 48                                  Chandrapur   Chandrapur      IN        co
# 49                                  Chandrapur   Chandrapur      IN       no2
#
#       value                 timestamp   unit source_name   latitude  \
# 0    910.00 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811
# 1    131.87 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811
# 2     15.57 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811
# 3     45.62 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811
# 4      4.49 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811
# 5    840.00 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.938906
# 6    166.55 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.938906
# 7     17.11 2017-02-12 01:45:00+00:00  µg/m³        CPCB  12.938906
# 8     40.94 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.938906
# 9      6.63 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.938906
# 10  1510.00 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.977347
# 11    46.86 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.977347
# 12   218.44 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.977347
# 13     5.88 2018-02-21 13:30:00+00:00  µg/m³        CPCB  12.977347
# 14   330.00 2018-02-21 23:45:00+00:00  µg/m³        CPCB  12.991670
# 15    23.67 2018-02-21 23:45:00+00:00  µg/m³        CPCB  12.991670
# 16    64.75 2018-02-21 23:45:00+00:00  µg/m³        CPCB  12.991670
# 17     3.88 2018-02-21 23:45:00+00:00  µg/m³        CPCB  12.991670
# 18   850.00 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.992514
# 19     6.13 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.992514
# 20    19.79 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.992514
# 21    70.00 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.992514
# 22     7.90 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.992514
# 23  5300.00 2017-10-11 08:45:00+00:00  µg/m³        CPCB  12.997114
# 24    12.39 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.997114
# 25     6.82 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.997114
# 26   111.73 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.997114
# 27    29.30 2018-02-22 03:45:00+00:00  µg/m³        CPCB  12.997114
# 28   970.00 2018-02-22 02:45:00+00:00  µg/m³        CPCB  13.033900
# 29    25.02 2018-02-22 02:45:00+00:00  µg/m³        CPCB  13.033900
# 30    43.79 2018-02-22 02:45:00+00:00  µg/m³        CPCB  13.033900
# 31     3.83 2018-02-22 02:45:00+00:00  µg/m³        CPCB  13.033900
# 32   310.00 2017-06-20 06:00:00+00:00  µg/m³        CPCB  17.423298
# 33    13.50 2017-06-20 06:00:00+00:00  µg/m³        CPCB  17.423298
# 34    23.00 2017-06-20 06:00:00+00:00  µg/m³        CPCB  17.423298
# 35     5.50 2017-06-20 06:00:00+00:00  µg/m³        CPCB  17.423298
# 36  1220.00 2018-02-22 03:00:00+00:00  µg/m³        CPCB  18.497484
# 37    15.76 2018-02-22 03:00:00+00:00  µg/m³        CPCB  18.497484
# 38   165.00 2018-02-22 03:00:00+00:00  µg/m³        CPCB  18.497484
# 39    66.00 2018-02-22 03:00:00+00:00  µg/m³        CPCB  18.497484
# 40    22.85 2018-02-22 03:00:00+00:00  µg/m³        CPCB  18.497484
# 41  1670.00 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.041847
# 42     7.04 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.041847
# 43    19.21 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.041847
# 44   295.97 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.041847
# 45    86.15 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.041847
# 46    18.35 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.041847
# 47    20.40 2017-10-04 04:15:00+00:00  µg/m³        CPCB  19.149400
# 48  1020.00 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.950000
# 49    18.80 2018-02-22 04:00:00+00:00  µg/m³        CPCB  19.950000
#
#     longitude  averaged_over_in_hours
# 0   77.609220                    0.25
# 1   77.609220                    0.25
# 2   77.609220                    0.25
# 3   77.609220                    0.25
# 4   77.609220                    0.25
# 5   77.697270                    0.25
# 6   77.697270                    0.25
# 7   77.697270                    0.25
# 8   77.697270                    0.25
# 9   77.697270                    0.25
# 10  77.570694                    0.25
# 11  77.570694                    0.25
# 12  77.570694                    0.25
# 13  77.570694                    0.25
# 14  77.545830                    0.25
# 15  77.545830                    0.25
# 16  77.545830                    0.25
# 17  77.545830                    0.25
# 18  80.237450                    0.25
# 19  80.237450                    0.25
# 20  80.237450                    0.25
# 21  80.237450                    0.25
# 22  80.237450                    0.25
# 23  80.191510                    0.25
# 24  80.191510                    0.25
# 25  80.191510                    0.25
# 26  80.191510                    0.25
# 27  80.191510                    0.25
# 28  77.513214                    0.25
# 29  77.513214                    0.25
# 30  77.513214                    0.25
# 31  77.513214                    0.25
# 32  78.474700                    0.25
# 33  78.474700                    0.25
# 34  78.474700                    0.25
# 35  78.474700                    0.25
# 36  73.813490                    0.25
# 37  73.813490                    0.25
# 38  73.813490                    0.25
# 39  73.813490                    0.25
# 40  73.813490                    0.25
# 41  72.865520                    0.25
# 42  72.865520                    0.25
# 43  72.865520                    0.25
# 44  72.865520                    0.25
# 45  72.865520                    0.25
# 46  72.865520                    0.25
# 47  72.998600                    0.25
# 48  79.300000                    0.25
# 49  79.300000                    0.25

# %% [markdown]
# ### Write SQL Query Now!!!

# %%
# Query to select all the items from the "city" column where the "country" column is 'US'
query = """
        SELECT city
        FROM `bigquery-public-data.openaq.global_air_quality`
        WHERE country = 'US'
        """

# %%
# Set up the query
query_job = client.query(query)

# %%
# API request - run the query, and return a pandas DataFrame
us_cities = query_job.to_dataframe()

# %%
# What five cities have the most measurements?
us_cities.city.value_counts().head()
# Out:
# Phoenix-Mesa-Scottsdale                     88
# Houston                                     82
# Los Angeles-Long Beach-Santa Ana            68
# Riverside-San Bernardino-Ontario            60
# New York-Northern New Jersey-Long Island    60
# Name: city, dtype: int64

# %%
query = """
        SELECT city, country
        FROM `bigquery-public-data.openaq.global_air_quality`
        WHERE country = 'US'
        """

# %%
# select all columns
query = """
        SELECT *
        FROM `bigquery-public-data.openaq.global_air_quality`
        WHERE country = 'US'
        """

# %%
# Query to get the score column from every row where the type column has value "job"
query = """
        SELECT score, title
        FROM `bigquery-public-data.hacker_news.full`
        WHERE type = "job" 
        """

# Create a QueryJobConfig object to estimate size of query without running it
dry_run_config = bigquery.QueryJobConfig(dry_run=True)

# API request - dry run query to estimate costs
dry_run_query_job = client.query(query, job_config=dry_run_config)

print("This query will process {} bytes.".format(dry_run_query_job.total_bytes_processed))
# Out:
# This query will process 494748929 bytes.

# %%
# Only run the query if it's less than 1 MB
ONE_MB = 1000*1000
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=ONE_MB)

# Set up the query (will only run if it's less than 1 MB)
safe_query_job = client.query(query, job_config=safe_config)

# API request - try to run the query, and return a pandas DataFrame
safe_query_job.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# <ipython-input-21-3ffb41147547> in <module>
#       7
#       8 # API request - try to run the query, and return a pandas DataFrame
# ----> 9 safe_query_job.to_dataframe()
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\cloud\bigquery\job\query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object, max_results, geography_as_object)
#    1641                 :mod:`shapely` library cannot be imported.
#    1642         """
# -> 1643         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1644         return query_result.to_dataframe(
#    1645             bqstorage_client=bqstorage_client,
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\cloud\bigquery\_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#      86     )
#      87     if progress_bar is None:
# ---> 88         return query_job.result(max_results=max_results)
#      89
#      90     i = 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\cloud\bigquery\job\query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1448                 do_get_result = job_retry(do_get_result)
#    1449
# -> 1450             do_get_result()
#    1451
#    1452         except exceptions.GoogleAPICallError as exc:
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     286                 sleep_generator,
#     287                 self._deadline,
# --> 288                 on_error=on_error,
#     289             )
#     290
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188     for sleep in sleep_generator:
#     189         try:
# --> 190             return target()
#     191
#     192         # pylint: disable=broad-except
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\cloud\bigquery\job\query.py in do_get_result()
#    1438                     self._job_retry = job_retry
#    1439
# -> 1440                 super(QueryJob, self).result(retry=retry, timeout=timeout)
#    1441
#    1442                 # Since the job could already be "done" (e.g. got a finished job
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\cloud\bigquery\job\base.py in result(self, retry, timeout)
#     725
#     726         kwargs = {} if retry is DEFAULT_RETRY else {"retry": retry}
# --> 727         return super(_AsyncJob, self).result(timeout=timeout, **kwargs)
#     728
#     729     def cancelled(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\google\api_core\future\polling.py in result(self, timeout, retry)
#     135             # pylint: disable=raising-bad-type
#     136             # Pylint doesn't recognize that this is valid in this case.
# --> 137             raise self._exception
#     138
#     139         return self._result
#
# InternalServerError: 500 Query exceeded limit for bytes billed: 1000000. 494927872 or higher required.
#
# (job ID: 15064789-0089-47d9-885e-d2fcf13f03cc)
#
#              -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:        SELECT score, title
#    3:        FROM `bigquery-public-data.hacker_news.full`
#    4:        WHERE type = "job"
#    5:
#     |    .    |    .    |    .    |    .    |    .    |

# %%
# Only run the query if it's less than 1 GB
ONE_GB = 1000*1000*1000
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=ONE_GB)

# Set up the query (will only run if it's less than 1 GB)
safe_query_job = client.query(query, job_config=safe_config)

# API request - try to run the query, and return a pandas DataFrame
job_post_scores = safe_query_job.to_dataframe()

# Print average score for job posts
job_post_scores.score.mean()
# Out:
# 1.7841263098272444
